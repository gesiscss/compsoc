# %% [markdown]
# [Home](index.ipynb) > [Notebooks](notebooks.ipynb) > Data Collections

# %% [markdown]
# <img style='float: left;' src='https://www.gesis.org/fileadmin/styles/img/gs_home_logo_en.svg'>

# %% [markdown]
# # ``compsoc`` – *Notebooks for Computational Sociology* (alpha)

# %% [markdown]
# [Notebooks](notebooks.ipynb) | [Infrastructure](infrastructure.ipynb) | [People](people.ipynb)

# %% [markdown]
# ***

# %% [markdown]
# ## 2. Data Collections
#
# The [introduction](introduction.ipynb) has laid out why digital behavioral data is catalyzing new social research into human behavior, presented a methodological framework and vocabulary for this endeavor, and stressed the importance of datasets rich in node attributes and types of tie. Here, we dive deeper into the notion of digital bevavioral data. We develop a unified data model that various sets of digital behavioral data can be mapped to. This is a necessary step for methods to be broadly applicable.
#
# DBD: "traces of behavior left by uses of, or harnessed by, digital technology"
#
# ---
#
# 1) Traces of behavior left by uses of digital technology, e.g.,
# typically online content creation,
# users' content creation on an online platform like hashtag used in a tweet,
# liking,
# following,
# commenting,
# tagging,
# browsing histories,
# search queries,
# purchase information,
# phone calls,
# Wikipedia page writing by editors
#
# 2) Traces of behavior harnessed by digital technology, e.g., (NOT FROM ACTIVE USE OF TECHNOLOGY BUT FROM TECHNOLOGY OPERATING IN BACKGROUND)
# GPS location recorded by mobile phone (NOT APP/PLATFORM USE),
# Bluetooth co-location (pairwise signal strength) (NOT APP/PLATFORM USE),
# proximity from RFID sensors (special case),
# authorships or, or citations made in, paper (WoS and DBLP as special cases of data collections curated by an organization)
#
# NOW DESCRIBE THE IDENTITY MODEL AND HOW ACTIVE TRACES BECOME PASSIVE TRACES
#
#
#
# 1 passive) "data generated by platforms as a by-product of users' online behavior",
# e.g.,
# personality profiles from active traces, inference of personal attributes from Facebook likes (Kosinski)
#
# 2 passive) "data posted by other users but linked to an individual",
# e.g.,
# getting tagged, reviewed, or rated,
# receiving likes or comments,
# discographies at discogs
#
# NOW MAP IDENTITY MODEL TO DATA MODEL
#
# now abstract these traces; DURKHEIM ETC; FACTS

# %% [markdown]
# |<img src='images/data_model.png' style='float: none; width: 460px'>|
# |:--|
# |<em style='float: center'>**Figure 1**: Unified model for digital behaioral data</em>|

# %% [markdown]
# Each dataset has its own notebook
# several steps to bring the data into the standardized form

# %% [markdown]
# In these notebooks, different datasets are provided in this standardized format:
#
# [Elite families](elite_families.ipynb): Multiplex ties in Renaissance Florence
#
# [Copenhagen Networks Study](copenhagen.ipynb): Multiplex interactions among 845 university students
#
# [Social Network Science (1916-2012)](sns.ipynb): Collaboration and language use in a scholarly field

# %% [markdown]
# ***

# %% [markdown]
# Powered by:
#
# <img src='images/logo_gesis_notebooks.png' style='height: 50px; float: left'>
# <img src='images/logo_jupyter.png' style='height: 50px; float: left; margin-left: 40px'>
# <img src='images/logo_python.png' style='height: 50px; float: left; margin-left: 20px'>
# <img src='images/logo_pandas.png' style='height: 50px; float: left; margin-left: 20px'>
